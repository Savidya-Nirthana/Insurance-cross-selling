# %% [markdown]
# ### download dataset
# dataset = https://www.kaggle.com/competitions/playground-series-s4e7/data

# %%
import json
with open('../artifacts/kaggle.json', 'r') as file:
    data = json.load(file)

# %%
import os
os.environ["KAGGLE_USERNAME"] = data['username']
os.environ["KAGGLE_KEY"] = data['key']

# %%
# !kaggle competitions download -c playground-series-s4e7 -p ../artifacts/
# Out:
# ...
#   0%|          | 0.00/247M [00:00<?, ?B/s]
#   0%|          | 1.00M/247M [00:01<04:34, 940kB/s]
#   1%|          | 2.00M/247M [00:01<02:33, 1.68MB/s]
#   1%|1         | 3.00M/247M [00:01<01:50, 2.32MB/s]
#   2%|1         | 4.00M/247M [00:01<01:29, 2.86MB/s]
#   2%|2         | 5.00M/247M [00:02<01:19, 3.20MB/s]
#   2%|2         | 6.00M/247M [00:02<01:16, 3.32MB/s]
#   3%|2         | 7.00M/247M [00:02<01:10, 3.57MB/s]
#   3%|3         | 8.00M/247M [00:03<01:18, 3.21MB/s]
#   4%|3         | 9.00M/247M [00:03<01:13, 3.41MB/s]
#   4%|4         | 10.0M/247M [00:03<01:08, 3.63MB/s]
#   4%|4         | 11.0M/247M [00:04<01:44, 2.37MB/s]
#   5%|4         | 12.0M/247M [00:04<01:44, 2.37MB/s]
#   5%|5         | 13.0M/247M [00:05<01:42, 2.39MB/s]
#   6%|5         | 14.0M/247M [00:05<01:30, 2.71MB/s]
#   6%|6         | 15.0M/247M [00:06<01:48, 2.24MB/s]
#   6%|6         | 16.0M/247M [00:06<01:37, 2.48MB/s]
#   7%|6         | 17.0M/247M [00:07<01:46, 2.27MB/s]
# ...

# %%
import zipfile

# %%
with zipfile.ZipFile('../artifacts/playground-series-s4e7.zip', 'r') as file:
    file.extractall('../artifacts')
